# %%
# Loading the Dataset to df

import pandas as pd

df = pd.read_csv("coin_Bitcoin.csv")
df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
df.select_dtypes(include='number').mean().to_frame().T
# Out:
#       SNo         High          Low        Open        Close        Volume  \
# 0  1496.0  6893.326038  6486.009539  6700.14624  6711.290443  1.090633e+10
#
#       Marketcap
# 0  1.208761e+11

# %%
df.select_dtypes(include='number').median().to_frame().T
# Out:
#       SNo         High     Low         Open        Close       Volume  \
# 0  1496.0  2387.610107  2178.5  2269.889893  2286.409912  946035968.0
#
#       Marketcap
# 0  3.741503e+10

# %%
df.select_dtypes(include='number').mode().iloc[0].to_frame().T
# Out:
#    SNo   High   Low    Open  Close  Volume     Marketcap
# 0  1.0  108.0  93.0  106.75  104.0     0.0  1.229098e+09

# %%
(df.select_dtypes(include='number').max() -
 df.select_dtypes(include='number').min()).to_frame().T
# Out:
#       SNo          High           Low          Open        Close  \
# 0  2990.0  64788.537812  62143.438365  63455.249872  63435.02693
#
#          Volume     Marketcap
# 0  3.509679e+11  1.185586e+12

# %%
df.select_dtypes(include='number').var().to_frame().T
# Out:
#         SNo          High           Low          Open         Close  \
# 0  745756.0  1.355555e+08  1.181359e+08  1.274199e+08  1.276480e+08
#
#          Volume     Marketcap
# 0  3.567925e+20  4.449730e+22

# %%
df.select_dtypes(include='number').std().to_frame().T
# Out:
#           SNo          High          Low          Open         Close  \
# 0  863.571653  11642.832456  10869.03213  11288.043736  11298.141921
#
#          Volume     Marketcap
# 0  1.888895e+10  2.109438e+11

# %%
(df.select_dtypes(include='number').quantile(0.75) -
 df.select_dtypes(include='number').quantile(0.25)).to_frame().T
# Out:
#       SNo         High          Low         Open        Close        Volume  \
# 0  1495.0  8297.747947  7866.920973  8139.210998  8145.669227  1.588978e+10
#
#       Marketcap
# 0  1.436902e+11

# %%
df.select_dtypes(include='number').skew().to_frame().T
# Out:
#    SNo      High       Low      Open     Close    Volume  Marketcap
# 0  0.0  3.012925  3.033504  3.025191  3.018634  3.742112   3.071752

# %%
df.select_dtypes(include='number').kurtosis().to_frame().T
# Out:
#    SNo      High      Low      Open    Close     Volume  Marketcap
# 0 -1.2  9.373806  9.66616  9.520448  9.47401  38.480451    9.73131
